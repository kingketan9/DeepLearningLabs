# 44          44   92.8  222.72  111.36  37.12  23.20  18.56  464
# 45          45   94.4  226.56  113.28  37.76  23.60  18.88  472
# 46          46   93.2  223.68  111.84  37.28  23.30  18.64  466
# 47          47  104.4  250.56  125.28  41.76  26.10  20.88  522
# 48          48  184.6  443.04  221.52  73.84  46.15  36.92  923
# 49          49  157.8  378.72  189.36  63.12  39.45  31.56  789

# %%
max = []
min = []

# %%
min_val = df['A'].min()
max_val = df['A'].max()

max.append(max_val)
min.append(min_val)
print("Minimum value:", min_val)
print("Maximum value:", max_val)
# Out:
# Minimum value: 21.6
# Maximum value: 199.4

# %%
min_val = df['B'].min()
max_val = df['B'].max()

max.append(max_val)
min.append(min_val)
print("Minimum value:", min_val)
print("Maximum value:", max_val)
# Out:
# Minimum value: 51.84
# Maximum value: 478.56

# %%
min_val = df['C'].min()
max_val = df['C'].max()

max.append(max_val)
min.append(min_val)
print("Minimum value:", min_val)
print("Maximum value:", max_val)
# Out:
# Minimum value: 25.92
# Maximum value: 239.28

# %%
min_val = df['D'].min()
max_val = df['D'].max()

max.append(max_val)
min.append(min_val)
print("Minimum value:", min_val)
print("Maximum value:", max_val)
# Out:
# Minimum value: 8.64
# Maximum value: 79.76

# %%
min_val = df['E'].min()
max_val = df['E'].max()

max.append(max_val)
min.append(min_val)
print("Minimum value:", min_val)
print("Maximum value:", max_val)
# Out:
# Minimum value: 5.4
# Maximum value: 49.85

# %%
min_val = df['F'].min()
max_val = df['F'].max()

max.append(max_val)
min.append(min_val)
print("Minimum value:", min_val)
print("Maximum value:", max_val)
# Out:
# Minimum value: 4.32
# Maximum value: 39.88

# %%
max
# Out:
# [199.4, 478.56, 239.28, 79.76, 49.85, 39.88]

# %%
min
# Out:
# [21.6, 51.84, 25.92, 8.64, 5.4, 4.32]

# %%
def check(upperb, lowerb, ip):
  lower_bound = lowerb
  upper_bound = upperb

  def label_number(number):
    if number >= lower_bound and number <= upper_bound:
        return 1
    else:
        return 0

  input_numbers = np.random.randint(0, 300, 1000)
  labels = [label_number(number) for number in input_numbers]

  split_ratio = 0.8
  split_index = int(split_ratio * len(input_numbers))
  train_X, train_y = input_numbers[:split_index], labels[:split_index]
  test_X, test_y = input_numbers[split_index:], labels[split_index:]

  classifier = DecisionTreeClassifier()
  classifier.fit(train_X.reshape(-1, 1), train_y)

  accuracy = classifier.score(test_X.reshape(-1, 1), test_y)
  print("Accuracy:", accuracy)

  new_number = ip
  prediction = classifier.predict([[new_number]])
  prediction = int(prediction)
  return prediction

# %%
input = [34, 60, 80, 90, 100, 120]

# %%
predict = list(map(lambda x,y,z: check(x,y,z), max, min, input))
# Out:
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0
# Accuracy: 1.0

# %%
predict
# Out:
# [1, 1, 1, 0, 0, 0]

# %%
def output(p):
  col_name = ['A','B','C','D','E','F']
  for i in range(len(p)):
    if p[i] == 1:
      print(col_name[i],"column is valid")
    else:
      print(col_name[i],"column is invalid")

# %%
output(predict)
# Out:
# A column is valid
# B column is valid
# C column is valid
# D column is invalid
# E column is invalid
# F column is invalid
